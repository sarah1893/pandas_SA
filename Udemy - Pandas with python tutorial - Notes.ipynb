# %%
import pandas as pd

# %%
data = pd.read_table('http://bit.ly/chiporders')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
data.shape
# Out:
# (4622, 5)

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data = pd.read_table('http://bit.ly/movieusers')

# %%
data
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# 5      7|57|M|administrator|91344
# 6      8|36|M|administrator|05201
# 7            9|29|M|student|01002
# 8            10|53|M|lawyer|90703
# 9             11|39|F|other|30329
# 10            12|28|F|other|06405
# 11         13|47|M|educator|29206
# 12        14|45|M|scientist|55106
# 13         15|49|F|educator|97301
# 14    16|21|M|entertainment|10309
# 15       17|30|M|programmer|06355
# 16            18|35|F|other|37212
# 17        19|40|M|librarian|02138
# 18        20|42|F|homemaker|95660
# 19           21|26|M|writer|30068
# 20           22|25|M|writer|40206
# 21           23|30|F|artist|48197
# 22           24|21|F|artist|94533
# 23         25|39|M|engineer|55107
# 24         26|49|M|engineer|21044
# 25        27|40|F|librarian|30030
# ...

# %%
data = pd.read_table('http://bit.ly/movieusers', sep='|')

# %%
data
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# 5      7  57  M  administrator  91344
# 6      8  36  M  administrator  05201
# 7      9  29  M        student  01002
# 8     10  53  M         lawyer  90703
# 9     11  39  F          other  30329
# 10    12  28  F          other  06405
# 11    13  47  M       educator  29206
# 12    14  45  M      scientist  55106
# 13    15  49  F       educator  97301
# 14    16  21  M  entertainment  10309
# 15    17  30  M     programmer  06355
# 16    18  35  F          other  37212
# 17    19  40  M      librarian  02138
# 18    20  42  F      homemaker  95660
# 19    21  26  M         writer  30068
# 20    22  25  M         writer  40206
# 21    23  30  F         artist  48197
# 22    24  21  F         artist  94533
# 23    25  39  M       engineer  55107
# ...

# %%
data = pd.read_table('http://bit.ly/movieusers', sep='|', header=None)

# %%
data
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# 5      6  42  M      executive  98101
# 6      7  57  M  administrator  91344
# 7      8  36  M  administrator  05201
# 8      9  29  M        student  01002
# 9     10  53  M         lawyer  90703
# 10    11  39  F          other  30329
# 11    12  28  F          other  06405
# 12    13  47  M       educator  29206
# 13    14  45  M      scientist  55106
# 14    15  49  F       educator  97301
# 15    16  21  M  entertainment  10309
# 16    17  30  M     programmer  06355
# 17    18  35  F          other  37212
# 18    19  40  M      librarian  02138
# 19    20  42  F      homemaker  95660
# 20    21  26  M         writer  30068
# 21    22  25  M         writer  40206
# 22    23  30  F         artist  48197
# 23    24  21  F         artist  94533
# ...

# %%
col_names = ['ID', 'Age', 'Genre', 'Profession', 'Salaire']

# %%
data = pd.read_table('http://bit.ly/movieusers', 
                     sep='|', 
                     header=None, 
                     names=col_names)

# %%
data
# Out:
#       ID  Age Genre     Profession Salaire
# 0      1   24     M     technician   85711
# 1      2   53     F          other   94043
# 2      3   23     M         writer   32067
# 3      4   24     M     technician   43537
# 4      5   33     F          other   15213
# 5      6   42     M      executive   98101
# 6      7   57     M  administrator   91344
# 7      8   36     M  administrator   05201
# 8      9   29     M        student   01002
# 9     10   53     M         lawyer   90703
# 10    11   39     F          other   30329
# 11    12   28     F          other   06405
# 12    13   47     M       educator   29206
# 13    14   45     M      scientist   55106
# 14    15   49     F       educator   97301
# 15    16   21     M  entertainment   10309
# 16    17   30     M     programmer   06355
# 17    18   35     F          other   37212
# 18    19   40     M      librarian   02138
# 19    20   42     F      homemaker   95660
# 20    21   26     M         writer   30068
# ...

# %%
data.Age
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
# 5      42
# 6      57
# 7      36
# 8      29
# 9      53
# 10     39
# 11     28
# 12     47
# 13     45
# 14     49
# 15     21
# 16     30
# 17     35
# 18     40
# 19     42
# 20     26
# 21     25
# 22     30
# 23     21
# 24     39
# 25     49
# 26     40
# 27     32
# 28     41
# 29      7
#        ..
# 913    44
# 914    50
# 915    27
# 916    22
# 917    40
# 918    25
# 919    30
# 920    20
# 921    29
# 922    21
# 923    29
# 924    18
# 925    49
# 926    23
# 927    21
# 928    44
# 929    28
# 930    60
# 931    58
# 932    28
# 933    61
# 934    42
# 935    24
# 936    48
# 937    38
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: Age, Length: 943, dtype: int64

# %%
data.new = data.Profession + data.Genre
# Out:
# C:\Users\ALIBAY\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
data['new'] = data.Profession + data.Genre

# %%
data
# Out:
#       ID  Age Genre     Profession Salaire             new
# 0      1   24     M     technician   85711     technicianM
# 1      2   53     F          other   94043          otherF
# 2      3   23     M         writer   32067         writerM
# 3      4   24     M     technician   43537     technicianM
# 4      5   33     F          other   15213          otherF
# 5      6   42     M      executive   98101      executiveM
# 6      7   57     M  administrator   91344  administratorM
# 7      8   36     M  administrator   05201  administratorM
# 8      9   29     M        student   01002        studentM
# 9     10   53     M         lawyer   90703         lawyerM
# 10    11   39     F          other   30329          otherF
# 11    12   28     F          other   06405          otherF
# 12    13   47     M       educator   29206       educatorM
# 13    14   45     M      scientist   55106      scientistM
# 14    15   49     F       educator   97301       educatorF
# ...

# %%
data = pd.read_csv('http://bit.ly/imdbratings') 
#ou data = pd.read_table('http://bit.ly/imdbratings', sep=',')

# %%
data.describe(include=['object'])
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
data.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
data.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
data.rename(columns = {'star_rating':'starRating'}, inplace=True)

# %%
data_cols = ['StarRating', 'Title', 'ContentRating', 'Genre', 'Duration', 'ActorsList']

# %%
data.columns = data_cols

# %%
data
# Out:
#      StarRating                                              Title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
# Suppression d'une colonne (axis = 1 -> drop qqlchse ds les colonnes) data.drop('Title', axis=1, inplace=True)

# %%
data.head(2)
# Out:
#    StarRating                     Title ContentRating  Genre  Duration  \
# 0         9.3  The Shawshank Redemption             R  Crime       142
# 1         9.2             The Godfather             R  Crime       175
#
#                                           ActorsList
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
# data.drop(['Genre', 'Duration'], axis=1, inplace=True)

# %%
# Suppression des 3 premières lignes data.drop([0, 1, 2], axis=0, inplace=True)

# %%
# Sorting Data Frame
# Trier une colonne 
data['Duration'].sort_values(ascending=False)
# Out:
# 476    242
# 157    238
# 78     229
# 142    224
# 445    220
# 85     216
# 204    212
# 17     207
# 767    205
# 630    202
# 7      201
# 2      200
# 335    197
# 385    197
# 8      195
# 620    194
# 424    193
# 220    191
# 671    191
# 40     189
# 316    189
# 89     189
# 184    188
# 318    188
# 611    187
# 132    186
# 245    184
# 109    183
# 166    182
# 361    181
#       ...
# 766     83
# 759     83
# 174     83
# 306     82
# 595     82
# 330     81
# 789     81
# 738     81
# 541     81
# 117     81
# 622     80
# 297     80
# 283     80
# 533     80
# 853     80
# 513     80
# 535     79
# 489     78
# 864     78
# 713     78
# 303     76
# 405     75
# 938     75
# 351     70
# 742     69
# 88      68
# 293     68
# 258     67
# 338     66
# 389     64
# Name: Duration, Length: 979, dtype: int64

# %%
# Trier le dataframe suivant une colonne
data.sort_values('Duration')
# Out:
#      StarRating                                          Title ContentRating  \
# 389         8.0                                         Freaks       UNRATED
# 338         8.0                            Battleship Potemkin       UNRATED
# 258         8.1                    The Cabinet of Dr. Caligari       UNRATED
# 293         8.1                                      Duck Soup        PASSED
# 88          8.4                                        The Kid     NOT RATED
# 742         7.6                                      Following             R
# 351         8.0                                   Frankenstein       UNRATED
# 938         7.4                            Alice in Wonderland             G
# 405         7.9                      The Bride of Frankenstein     NOT RATED
# 303         8.0                 The Nightmare Before Christmas            PG
# 713         7.6                                The Jungle Book      APPROVED
# ...

# %%
# Trier le dataframe suivant une colonne (ordre décroissant)
data.sort_values('Duration', ascending=False)
# Out:
#      StarRating                                          Title ContentRating  \
# 476         7.8                                         Hamlet         PG-13
# 157         8.2                             Gone with the Wind             G
# 78          8.4                    Once Upon a Time in America             R
# 142         8.3              Lagaan: Once Upon a Time in India            PG
# 445         7.9                           The Ten Commandments      APPROVED
# 85          8.4                             Lawrence of Arabia            PG
# 204         8.1                                        Ben-Hur             G
# 17          8.7                                  Seven Samurai       UNRATED
# 767         7.6                It's a Mad, Mad, Mad, Mad World      APPROVED
# 630         7.7                                      Malcolm X         PG-13
# 7           8.9  The Lord of the Rings: The Return of the King         PG-13
# ...

# %%
data.sort_values(['Genre', 'Duration'])
# Out:
#      StarRating                           Title ContentRating     Genre  \
# 533         7.8                    Run Lola Run             R    Action
# 633         7.7                    The Warriors             R    Action
# 455         7.9                           Taken         PG-13    Action
# 685         7.7                     First Blood             R    Action
# 744         7.6     Mad Max 2: The Road Warrior             R    Action
# 619         7.7                Forbidden Planet        PASSED    Action
# 276         8.1            A Fistful of Dollars             R    Action
# 403         7.9                      Ying xiong         PG-13    Action
# 552         7.8                  Kung Fu Hustle             R    Action
# 740         7.6            The Raid: Redemption             R    Action
# 327         8.0    The Adventures of Robin Hood            PG    Action
# 515         7.8                     Dirty Harry             R    Action
# ...

# %%
# Filtering Data 
data[data.Duration >= 175]
# Out:
#      StarRating                                              Title  \
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 14          8.8              The Lord of the Rings: The Two Towers
# 17          8.7                                      Seven Samurai
# 26          8.6                       Once Upon a Time in the West
# 40          8.5                                     The Green Mile
# 78          8.4                        Once Upon a Time in America
# 82          8.4                                         Braveheart
# 85          8.4                                 Lawrence of Arabia
# 89          8.4                                             Swades
# ...

# %%
# Filtering Data 
data[data.Duration >= 175].Genre
# Out:
# 1          Crime
# 2          Crime
# 7      Adventure
# 8      Biography
# 10     Adventure
# 14     Adventure
# 17         Drama
# 26       Western
# 40         Crime
# 78         Crime
# 82        Action
# 85     Adventure
# 89         Drama
# 93        Comedy
# 109       Comedy
# 132        Drama
# 142    Adventure
# 143    Biography
# 156    Biography
# 157        Drama
# 166        Drama
# 184        Drama
# 204    Adventure
# 220    Biography
# 245    Adventure
# 300        Crime
# 316        Drama
# 318        Drama
# 335        Drama
# 339    Adventure
# 361        Drama
# 385       Action
# 424    Adventure
# 445    Adventure
# 456        Drama
# 476        Drama
# 534       Action
# 611       Comedy
# 620        Drama
# 630    Biography
# 671       Action
# 767       Action
# 941        Drama
# Name: Genre, dtype: object

# %%
import random
# Choix au hasard des élméénts d'une liste avec remise 
four_with_replacement = [random.choice(range(1,10))
                          for _ in range(9)]
four_with_replacement
# Out:
# [8, 3, 5, 7, 5, 2, 4, 7, 6]

# %%
# Filter Multiple Criteria
data[(data.ContentRating == 'R') & (data.Genre == 'Crime')]
# Out:
#      StarRating                             Title ContentRating  Genre  \
# 0           9.3          The Shawshank Redemption             R  Crime
# 1           9.2                     The Godfather             R  Crime
# 2           9.1            The Godfather: Part II             R  Crime
# 4           8.9                      Pulp Fiction             R  Crime
# 21          8.7                       City of God             R  Crime
# 23          8.7                The Usual Suspects             R  Crime
# 28          8.6            Leon: The Professional             R  Crime
# 34          8.6                American History X             R  Crime
# 40          8.5                    The Green Mile             R  Crime
# 49          8.5                      The Departed             R  Crime
# 78          8.4       Once Upon a Time in America             R  Crime
# 90          8.4                    Reservoir Dogs             R  Crime
# ...

# %%
data[(data.Genre == 'Crime') | (data.Genre == 'Action') | (data.Genre == 'Drama')]
# Version améliorée 
data.Genre.isin(['Crime', 'Drama', 'Action'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11      True
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26     False
# 27      True
# 28      True
# 29     False
#        ...
# 949    False
# 950     True
# 951     True
# 952    False
# 953    False
# 954     True
# 955     True
# 956    False
# 957    False
# 958     True
# 959    False
# 960    False
# 961    False
# 962    False
# 963     True
# 964    False
# 965    False
# 966    False
# 967     True
# 968     True
# 969     True
# 970     True
# 971    False
# 972     True
# 973     True
# 974    False
# 975    False
# 976     True
# 977    False
# 978     True
# Name: Genre, Length: 979, dtype: bool

# %%
# Selective Columns and rows 
data = pd.read_csv('http://bit.ly/imdbratings', 
                   #usecols = ['title', 'genre']
                  )

# %%
# Selective Columns and rows 
data = pd.read_csv('http://bit.ly/imdbratings', 
                   nrows=5)

# %%
# Selective Columns and rows 
data = pd.read_csv('http://bit.ly/imdbratings', 
                   usecols = ['title', 'genre'], nrows=5)

# %%
data
# Out:
#                       title   genre
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action
# 4              Pulp Fiction   Crime

# %%
for i in data.title:
    print(i)
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather: Part II
# The Dark Knight
# Pulp Fiction

# %%
for index, row in data.iterrows():
    print(index, row.title, row.genre)
# Out:
# 0 The Shawshank Redemption Crime
# 1 The Godfather Crime
# 2 The Godfather: Part II Crime
# 3 The Dark Knight Action
# 4 Pulp Fiction Crime

# %%
data.mean()
# Out:
# Series([], dtype: float64)

# %%
# String Methods in Pandas 
'hello'.upper()
# Out:
# 'HELLO'

# %%
data.title.str.upper()
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %%
data[data.title.str.contains('The')]
# Out:
#                       title   genre
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action

# %%
# Changing the data types 
data.dtypes
# Out:
# title    object
# genre    object
# dtype: object

# %%
data.duration = data.duration.astype(float)

# %%
# Selective Columns and rows 
data = pd.read_csv('http://bit.ly/imdbratings',
                  dtype = {'duration' : float })

# %%
data = pd.read_table('http://bit.ly/chiporders')

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
data.item_price.str.replace('$', '').astype(float).mean()
# Out:
# 7.464335785374397

# %%
data.item_name.str.contains('and').head().astype('int')
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: item_name, dtype: int32

# %%
# 18. Group by functions 
data.groupby('genre').duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
# 18. Group by functions 
data.groupby('genre').duration.agg(['min', 'median', 'max', 'mean', 'count'])
# Out:
#              min  median    max        mean  count
# genre
# Action      80.0   125.0  205.0  126.485294    136
# Adventure   89.0   127.0  224.0  134.840000     75
# Animation   75.0    94.5  134.0   96.596774     62
# Biography   85.0   127.0  202.0  131.844156     77
# Comedy      68.0   104.0  187.0  107.602564    156
# Crime       67.0   118.0  229.0  122.298387    124
# Drama       64.0   123.0  242.0  126.539568    278
# Family     100.0   107.5  115.0  107.500000      2
# Fantasy    112.0   112.0  112.0  112.000000      1
# Film-Noir   88.0    93.0  111.0   97.333333      3
# History     66.0    66.0   66.0   66.000000      1
# Horror      70.0   104.0  146.0  102.517241     29
# Mystery     69.0   115.0  160.0  115.625000     16
# Sci-Fi      91.0   113.0  132.0  109.000000      5
# Thriller   107.0   116.0  120.0  114.200000      5
# Western     85.0   135.0  175.0  136.666667      9

# %%
# 19. Functions on Series 
data.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
data.genre.value_counts().head()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Name: genre, dtype: int64

# %%
data.genre.value_counts(normalize=True).head()
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Name: genre, dtype: float64

# %%
data.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
data.genre.nunique()
# Out:
# 16

# %%
pd.crosstab(data.genre, data.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %%
# 20. Plotting series in pandas
# %matplotlib inline 
data.duration.plot(kind='hist')

# %%
data.genre.value_counts().plot(kind='bar')

# %%
# 21. Dealing with Null values 
data = pd.read_csv('http://bit.ly/uforeports')

# %%
data.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
data.isnull().head()
# data.notnull().head()
# Out:
#     City  Colors Reported  Shape Reported  State   Time
# 0  False             True           False  False  False
# 1  False             True           False  False  False
# 2  False             True           False  False  False
# 3  False             True           False  False  False
# 4  False             True           False  False  False

# %%
data.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
data[data.City.isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
# 22. Uses of index 
data.index
data.set_index('City')
# Out:
#                      Colors Reported Shape Reported State              Time
# City
# Ithaca                           NaN       TRIANGLE    NY    6/1/1930 22:00
# Willingboro                      NaN          OTHER    NJ   6/30/1930 20:00
# Holyoke                          NaN           OVAL    CO   2/15/1931 14:00
# Abilene                          NaN           DISK    KS    6/1/1931 13:00
# New York Worlds Fair             NaN          LIGHT    NY   4/18/1933 19:00
# Valley City                      NaN           DISK    ND   9/15/1934 15:30
# Crater Lake                      NaN         CIRCLE    CA    6/15/1935 0:00
# Alma                             NaN           DISK    MI    7/15/1936 0:00
# Eklutna                          NaN          CIGAR    AK  10/15/1936 17:00
# Hubbard                          NaN       CYLINDER    OR    6/15/1937 0:00
# Fontana                          NaN          LIGHT    CA   8/15/1937 21:00
# ...

# %%
# 23. Column in index
data.index.name = None

# %%
data.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
data.loc[0, :]
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry', index_col = 'country')

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
# Out:
# C:\Users\ALIBAY\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 14
